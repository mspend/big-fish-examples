# %%
import os
import bigfish
import bigfish.stack as stack
from pathlib import Path

root_path = Path("/data/smfish/20250129_Bartelle_smFISH_control")

# %%
for tile in range(0,154):
    tiff_path = root_path / str("data_r0001_tile" + str(tile).zfill(4) + "_1") / str("data_r0001_tile" + str(tile).zfill(4) + "_NDTiffStack.tif")
    image = stack.read_image(str(tiff_path))
    print(tiff_path)
    print(image.shape)

# %%
for round in range(1,9):
    for tile in range(0,154):
        tiff_path = root_path / str("data_r" + str(round).zfill(4) + "_tile" + str(tile).zfill(4) + "_1") / str("data_r" + str(round).zfill(4) + "_tile" + str(tile).zfill(4) + "_NDTiffStack.tif")
        print(tiff_path)
        image = stack.read_image(str(tiff_path))
        print(image.shape)
# Out:
# /data/smfish/20250129_Bartelle_smFISH_control/data_r0001_tile0000_1/data_r0001_tile0000_NDTiffStack.tif
# (57, 2048, 2048, 3)
# /data/smfish/20250129_Bartelle_smFISH_control/data_r0001_tile0001_1/data_r0001_tile0001_NDTiffStack.tif
# (57, 2048, 2048, 3)
# /data/smfish/20250129_Bartelle_smFISH_control/data_r0001_tile0002_1/data_r0001_tile0002_NDTiffStack.tif
# (57, 2048, 2048, 3)
# /data/smfish/20250129_Bartelle_smFISH_control/data_r0001_tile0003_1/data_r0001_tile0003_NDTiffStack.tif
# (57, 2048, 2048, 3)
# /data/smfish/20250129_Bartelle_smFISH_control/data_r0001_tile0004_1/data_r0001_tile0004_NDTiffStack.tif
# (57, 2048, 2048, 3)
# /data/smfish/20250129_Bartelle_smFISH_control/data_r0001_tile0005_1/data_r0001_tile0005_NDTiffStack.tif
# (57, 2048, 2048, 3)
# /data/smfish/20250129_Bartelle_smFISH_control/data_r0001_tile0006_1/data_r0001_tile0006_NDTiffStack.tif
# (57, 2048, 2048, 3)
# ...
